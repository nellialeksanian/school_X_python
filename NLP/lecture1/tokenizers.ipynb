# %%
# %pip install nltk
# Out:
# ...
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.5 MB 187.9 kB/s eta 0:00:08
#      - -------------------------------------- 0.0/1.5 MB 196.9 kB/s eta 0:00:08
#      - -------------------------------------- 0.1/1.5 MB 252.2 kB/s eta 0:00:06
#      -- ------------------------------------- 0.1/1.5 MB 385.0 kB/s eta 0:00:04
#      ----- ---------------------------------- 0.2/1.5 MB 689.2 kB/s eta 0:00:02
#      -------- ------------------------------- 0.3/1.5 MB 855.7 kB/s eta 0:00:02
#      ---------- ----------------------------- 0.4/1.5 MB 983.6 kB/s eta 0:00:02
#      ----------------- ---------------------- 0.6/1.5 MB 1.5 MB/s eta 0:00:01
#      ------------------------------- -------- 1.2/1.5 MB 2.4 MB/s eta 0:00:01
# ...

# %%
# %pip install spacy
# Out:
# ...
#
#   Obtaining dependency information for spacy from https://files.pythonhosted.org/packages/ad/ca/1f6d0446d8ed55290ca49db6416c4faeeca579d127f379a2e360f179b69c/spacy-3.7.1-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for spacy-loggers<2.0.0,>=1.0.0 from https://files.pythonhosted.org/packages/33/78/d1a1a026ef3af911159398c939b1509d5c36fe524c7b644f34a5146c4e16/spacy_loggers-1.0.5-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for murmurhash<1.1.0,>=0.28.0 from https://files.pythonhosted.org/packages/71/46/af01a20ec368bd9cb49a1d2df15e3eca113bbf6952cc1f2a47f1c6801a7f/murmurhash-1.0.10-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for cymem<2.1.0,>=2.0.2 from https://files.pythonhosted.org/packages/c1/c3/dd044e6f62a3d317c461f6f0c153c6573ed13025752d779e514000c15dd2/cymem-2.0.8-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
import nltk, spacy

# %%
book = open("the_great_gatsby.txt", encoding="utf8").read()

# %%
bt = nltk.tokenize.BlanklineTokenizer()
print(bt.tokenize(book))  #разделитель пустые строки
# Out:
# ['CHAPTER I\nIn my younger and more vulnerable years my father gave me some advice that I’ve been turning over in my mind ever since. “Whenever you feel like criticizing any one,” he told me, “just remember that all the people in this world haven’t had the advantages that you’ve had.”He didn’t say any more, but we’ve always been unusually communicative in a reserved way, and I understood that he meant a great deal more than that. In consequence, I’m inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores. The abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college I was unjustly accused of being a politician, because I was privy to the secret grief’s of wild, unknown men. Most of the confidences were unsought—frequently I have feigned sleep, preoccupation, or a hostile levity when I realized by some unmistakable si
# ...

# %%
syl = nltk.tokenize.LegalitySyllableTokenizer()
print(syl.tokenize(book))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\User\OneDrive\Desktop\schoolX\NLP\lecture1\lecture1.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Desktop/schoolX/NLP/lecture1/lecture1.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> syl = nltk.tokenize.LegalitySyllableTokenizer()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Desktop/schoolX/NLP/lecture1/lecture1.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> print(syl.tokenize(book))
#
# TypeError: LegalitySyllableTokenizer.__init__() missing 1 required positional argument: 'tokenized_source_text'

# %%
line = nltk.tokenize.LineTokenizer()
print(line.tokenize(book))
# Out:
# ['CHAPTER I', 'In my younger and more vulnerable years my father gave me some advice that I’ve been turning over in my mind ever since. “Whenever you feel like criticizing any one,” he told me, “just remember that all the people in this world haven’t had the advantages that you’ve had.”He didn’t say any more, but we’ve always been unusually communicative in a reserved way, and I understood that he meant a great deal more than that. In consequence, I’m inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores. The abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college I was unjustly accused of being a politician, because I was privy to the secret grief’s of wild, unknown men. Most of the confidences were unsought—frequently I have feigned sleep, preoccupation, or a hostile levity when I realized by some unmistakable 
# ...

# %%
mwe = nltk.tokenize.MWETokenizer()
print(mwe.tokenize(book))
# Out:
# ['C', 'H', 'A', 'P', 'T', 'E', 'R', ' ', 'I', '\n', 'I', 'n', ' ', 'm', 'y', ' ', 'y', 'o', 'u', 'n', 'g', 'e', 'r', ' ', 'a', 'n', 'd', ' ', 'm', 'o', 'r', 'e', ' ', 'v', 'u', 'l', 'n', 'e', 'r', 'a', 'b', 'l', 'e', ' ', 'y', 'e', 'a', 'r', 's', ' ', 'm', 'y', ' ', 'f', 'a', 't', 'h', 'e', 'r', ' ', 'g', 'a', 'v', 'e', ' ', 'm', 'e', ' ', 's', 'o', 'm', 'e', ' ', 'a', 'd', 'v', 'i', 'c', 'e', ' ', 't', 'h', 'a', 't', ' ', 'I', '’', 'v', 'e', ' ', 'b', 'e', 'e', 'n', ' ', 't', 'u', 'r', 'n', 'i', 'n', 'g', ' ', 'o', 'v', 'e', 'r', ' ', 'i', 'n', ' ', 'm', 'y', ' ', 'm', 'i', 'n', 'd', ' ', 'e', 'v', 'e', 'r', ' ', 's', 'i', 'n', 'c', 'e', '.', ' ', '“', 'W', 'h', 'e', 'n', 'e', 'v', 'e', 'r', ' ', 'y', 'o', 'u', ' ', 'f', 'e', 'e', 'l', ' ', 'l', 'i', 'k', 'e', ' ', 'c', 'r', 'i', 't', 'i', 'c', 'i', 'z', 'i', 'n', 'g', ' ', 'a', 'n', 'y', ' ', 'o', 'n', 'e', ',', '”', ' ', 'h', 'e', ' ', 't', 'o', 'l', 'd', ' ', 'm', 'e', ',', ' ', '“', 'j', 'u', 's', 't', ' ', 'r', 'e', 'm', 'e', '
# ...

# %%
wordtok = nltk.tokenize.NLTKWordTokenizer()
print(wordtok.tokenize(book))
# Out:
# ['CHAPTER', 'I', 'In', 'my', 'younger', 'and', 'more', 'vulnerable', 'years', 'my', 'father', 'gave', 'me', 'some', 'advice', 'that', 'I', '’', 've', 'been', 'turning', 'over', 'in', 'my', 'mind', 'ever', 'since.', '“', 'Whenever', 'you', 'feel', 'like', 'criticizing', 'any', 'one', ',', '”', 'he', 'told', 'me', ',', '“', 'just', 'remember', 'that', 'all', 'the', 'people', 'in', 'this', 'world', 'haven', '’', 't', 'had', 'the', 'advantages', 'that', 'you', '’', 've', 'had.', '”', 'He', 'didn', '’', 't', 'say', 'any', 'more', ',', 'but', 'we', '’', 've', 'always', 'been', 'unusually', 'communicative', 'in', 'a', 'reserved', 'way', ',', 'and', 'I', 'understood', 'that', 'he', 'meant', 'a', 'great', 'deal', 'more', 'than', 'that.', 'In', 'consequence', ',', 'I', '’', 'm', 'inclined', 'to', 'reserve', 'all', 'judgments', ',', 'a', 'habit', 'that', 'has', 'opened', 'up', 'many', 'curious', 'natures', 'to', 'me', 'and', 'also', 'made', 'me', 'the', 'victim', 'of', 'not', 'a', 'few', 'veter
# ...

# %%
punk = nltk.tokenize.PunktSentenceTokenizer()
print(punk.tokenize(book))
# Out:
# ['CHAPTER I\nIn my younger and more vulnerable years my father gave me some advice that I’ve been turning over in my mind ever since.', '“Whenever you feel like criticizing any one,” he told me, “just remember that all the people in this world haven’t had the advantages that you’ve had.”He didn’t say any more, but we’ve always been unusually communicative in a reserved way, and I understood that he meant a great deal more than that.', 'In consequence, I’m inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores.', 'The abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college I was unjustly accused of being a politician, because I was privy to the secret grief’s of wild, unknown men.', 'Most of the confidences were unsought—frequently I have feigned sleep, preoccupation, or a hostile levity when I realized by some unm
# ...

# %%
reg = nltk.tokenize.RegexpTokenizer()
print(reg.tokenize(book))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\User\OneDrive\Desktop\schoolX\NLP\lecture1\lecture1.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Desktop/schoolX/NLP/lecture1/lecture1.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> reg = nltk.tokenize.RegexpTokenizer()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Desktop/schoolX/NLP/lecture1/lecture1.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> print(reg.tokenize(book))
#
# TypeError: RegexpTokenizer.__init__() missing 1 required positional argument: 'pattern'

# %%
rep = nltk.tokenize.ReppTokenizer()
print(rep.tokenize(book))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\User\OneDrive\Desktop\schoolX\NLP\lecture1\lecture1.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Desktop/schoolX/NLP/lecture1/lecture1.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> rep = nltk.tokenize.ReppTokenizer()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Desktop/schoolX/NLP/lecture1/lecture1.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> print(rep.tokenize(book))
#
# TypeError: ReppTokenizer.__init__() missing 1 required positional argument: 'repp_dir'

# %%
se = nltk.tokenize.SExprTokenizer()
print(se.tokenize(book))
# Out:
# ['CHAPTER', 'I', 'In', 'my', 'younger', 'and', 'more', 'vulnerable', 'years', 'my', 'father', 'gave', 'me', 'some', 'advice', 'that', 'I’ve', 'been', 'turning', 'over', 'in', 'my', 'mind', 'ever', 'since.', '“Whenever', 'you', 'feel', 'like', 'criticizing', 'any', 'one,”', 'he', 'told', 'me,', '“just', 'remember', 'that', 'all', 'the', 'people', 'in', 'this', 'world', 'haven’t', 'had', 'the', 'advantages', 'that', 'you’ve', 'had.”He', 'didn’t', 'say', 'any', 'more,', 'but', 'we’ve', 'always', 'been', 'unusually', 'communicative', 'in', 'a', 'reserved', 'way,', 'and', 'I', 'understood', 'that', 'he', 'meant', 'a', 'great', 'deal', 'more', 'than', 'that.', 'In', 'consequence,', 'I’m', 'inclined', 'to', 'reserve', 'all', 'judgments,', 'a', 'habit', 'that', 'has', 'opened', 'up', 'many', 'curious', 'natures', 'to', 'me', 'and', 'also', 'made', 'me', 'the', 'victim', 'of', 'not', 'a', 'few', 'veteran', 'bores.', 'The', 'abnormal', 'mind', 'is', 'quick', 'to', 'detect', 'and', 'attach', 'i
# ...

# %%
space = nltk.tokenize.SpaceTokenizer()
print(space.tokenize(book))
# Out:
# ['CHAPTER', 'I\nIn', 'my', 'younger', 'and', 'more', 'vulnerable', 'years', 'my', 'father', 'gave', 'me', 'some', 'advice', 'that', 'I’ve', 'been', 'turning', 'over', 'in', 'my', 'mind', 'ever', 'since.', '“Whenever', 'you', 'feel', 'like', 'criticizing', 'any', 'one,”', 'he', 'told', 'me,', '“just', 'remember', 'that', 'all', 'the', 'people', 'in', 'this', 'world', 'haven’t', 'had', 'the', 'advantages', 'that', 'you’ve', 'had.”He', 'didn’t', 'say', 'any', 'more,', 'but', 'we’ve', 'always', 'been', 'unusually', 'communicative', 'in', 'a', 'reserved', 'way,', 'and', 'I', 'understood', 'that', 'he', 'meant', 'a', 'great', 'deal', 'more', 'than', 'that.', 'In', 'consequence,', 'I’m', 'inclined', 'to', 'reserve', 'all', 'judgments,', 'a', 'habit', 'that', 'has', 'opened', 'up', 'many', 'curious', 'natures', 'to', 'me', 'and', 'also', 'made', 'me', 'the', 'victim', 'of', 'not', 'a', 'few', 'veteran', 'bores.', 'The', 'abnormal', 'mind', 'is', 'quick', 'to', 'detect', 'and', 'attach', 'its
# ...

# %%
stan = nltk.tokenize.StanfordSegmenter()
print(stan.tokenize(book))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7648\2696543515.py:1: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.parse.corenlp.CoreNLPTokenizer instead.'
#   stan = nltk.tokenize.StanfordSegmenter()
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# c:\Users\User\OneDrive\Desktop\schoolX\NLP\lecture1\lecture1.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Desktop/schoolX/NLP/lecture1/lecture1.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> stan = nltk.tokenize.StanfordSegmenter()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/OneDrive/Desktop/schoolX/NLP/lecture1/lecture1.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> print(stan.tokenize(book))
#
# ...

# %%
syllab = nltk.tokenize.SyllableTokenizer()
print(syllab.tokenize(book))
# Out:
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nltk\tokenize\sonority_sequencing.py:102: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: ' '
#   warnings.warn(
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nltk\tokenize\sonority_sequencing.py:102: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '
# '
#   warnings.warn(
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\nltk\tokenize\sonority_sequencing.py:102: UserWarning: Character not defined in sonority_hierarchy, assigning as vowel: '’'
#   warnings.warn(
# ...
