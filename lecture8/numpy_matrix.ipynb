# %%
# %pip install -Uq numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
matrix1 = np.array([
    [1,1,1],
    [1,2,3],
    [11,12,13],
    [11,22,23]
]
)

matrix2 = np.array([
    [2,1,1],
    [1,4,3],
    [11,34,13],
    [10,22,33]
]
)

# %%
matrix1*2
# Out:
# array([[ 2,  2,  2],
#        [ 2,  4,  6],
#        [22, 24, 26],
#        [22, 44, 46]])

# %%
matrix1*matrix2
# Out:
# array([[  2,   1,   1],
#        [  1,   8,   9],
#        [121, 408, 169],
#        [110, 484, 759]])
