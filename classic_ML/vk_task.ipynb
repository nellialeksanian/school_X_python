# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('python_task_dataset.csv')

# %%
data['adv_type'].unique()
# Out:
# array(['multi', 'video'], dtype=object)

# %%
data['device_type'].unique()
# Out:
# array(['android', 'ios'], dtype=object)

# %%
data['region_id'].unique()
# Out:
# array([2, 1])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265403 entries, 0 to 265402
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   device_id    265403 non-null  int64
#  1   device_type  265403 non-null  object
#  2   datetime     265403 non-null  object
#  3   ev_type      265403 non-null  int64
#  4   adv_type     265403 non-null  object
#  5   region_id    265403 non-null  int64
#  6   age          265403 non-null  int64
#  7   gender       265403 non-null  int64
# dtypes: int64(5), object(3)
# memory usage: 16.2+ MB

# %%
gender_evtype = data.groupby("gender")['ev_type'].sum()
gender_evtype
# Out:
# gender
# 0     130
# 1    3943
# 2      35
# Name: ev_type, dtype: int64

# %%
plt.bar(gender_evtype.index, gender_evtype.values)
plt.show()

# %%
device_evtype = data.groupby('device_type')['ev_type'].sum()

# %%
plt.bar(device_evtype.index, device_evtype.values)
plt.show()

# %%
device_evtype['android']/data["device_type"].value_counts()['android']
# Out:
# 0.016435180122049912

# %%
device_evtype['ios']/data["device_type"].value_counts()['ios']
# Out:
# 0.009535970441208432

# %%
gender_evtype[1] / data['gender'].value_counts()[1]
# Out:
# 0.017399477530271473

# %%
gender_evtype[2] / data['gender'].value_counts()[2]
# Out:
# 0.003352490421455939
