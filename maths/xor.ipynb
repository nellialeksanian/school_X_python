# %%
# %pip install -Uq tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -Uq matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

# %%
X = np.array([[-1, -1], [-1, 1], [1, -1], [1, 1]])
Y = np.array([[0], [1], [1], [0]])

# %%
model = Sequential()
model.add(Dense(units=2, input_dim=2, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X, Y, epochs=15000, verbose=0)

# %%
predictions = model.predict(X)
rounded_predictions = [int(round(p[0])) for p in predictions]
print(f"Predicted results: {rounded_predictions}")
# Out:
# 1/1 [==============================] - 0s 51ms/step
# Predicted results: [0, 1, 1, 0]

# %%
print(model.evaluate(X, Y))
# Out:
# 1/1 [==============================] - 0s 70ms/step - loss: 1.6076e-06 - accuracy: 1.0000
# [1.6075678104243707e-06, 1.0]

# %%
plt.plot(history.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')
